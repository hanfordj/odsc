# %%
# Sneak peek into some geometric feature engineering to add centroids of the parcels
import numpy as np
import geopandas as gpd

stp_sales_2015 = gpd.read_file('./data/stpete_sales_2015.shp')
stp_sales_2015["x"] = stp_sales_2015.centroid.map(lambda p: p.x)
stp_sales_2015["y"] = stp_sales_2015.centroid.map(lambda p: p.y)
stp_sales_2015.head()
# Out:
#    AVE_FAM_SZ  AVE_HH_SZ  CentroidX  CentroidY  HS_PER_AC  MEDFINCOME  \
# 0    2.777506       2.19 -82.642882  27.810570   4.596851       68229
# 1    2.777506       2.19 -82.646179  27.811467   4.596851       68229
# 2    2.777506       2.19 -82.644930  27.812377   4.596851       68229
# 3    2.777506       2.19 -82.643034  27.813685   4.596851       68229
# 4    2.777506       2.19 -82.644526  27.813679   4.596851       68229
#
#    MEDHHINC  MEDOOHVAL  MED_AGE  PCT_AMERI    ...      taxable_va  tif_flag_t  \
# 0     54321     125200       46        0.0    ...           34513        None
# 1     54321     125200       46        0.0    ...           47710        None
# 2     54321     125200       46        0.0    ...          128088        None
# 3     54321     125200       46        0.0    ...           37048        None
# 4     54321     125200       46        0.0    ...          138960        None
#
#    tot_effect  tot_gross_  tot_living  total_livi  views  year_built  \
# 0        1164        1386        1048           1   None        1960
# 1        1672        2102        1486           1   None        1986
# 2        1626        1872        1468           1   None        1979
# 3        1855        2440        1680           1   None        1967
# 4        1524        1841        1453           1   None        1942
#
#            x          y
# 0 -82.642882  27.810570
# 1 -82.646179  27.811467
# 2 -82.644930  27.812377
# 3 -82.643034  27.813685
# 4 -82.644526  27.813679
#
# [5 rows x 101 columns]

# %%
# Open the St. Pete Census ACS in PySAL
import pysal
stp_parcels = pysal.open('./data/stpete_cenacs_2014.shp')

# %%
# Create a queen contiguity 1st order weights matrix and show the histogram
w = pysal.queen_from_shapefile("./data/stpete_cenacs_2014.shp")
w.histogram
# Out:
# [(1, 1),
#  (2, 2),
#  (3, 10),
#  (4, 20),
#  (5, 48),
#  (6, 57),
#  (7, 58),
#  (8, 21),
#  (9, 8),
#  (10, 2),
#  (11, 2),
#  (12, 0),
#  (13, 0),
#  (14, 1),
#  (15, 0),
#  (16, 0),
#  (17, 1)]

# %%
# Get the minimum nearest neighbor distance for the census block groups
thresh = pysal.min_threshold_dist_from_shapefile("./data/stpete_sales_2015.shp")
thresh
# Out:
# 0.005025135774761472

# %%
# Create distance based W matrix based on threshold value
wt = pysal.threshold_binaryW_from_shapefile("./data/stpete_sales_2015.shp", thresh)
wt.histogram
# Out:
# [(1, 1),
#  (2, 2),
#  (3, 2),
#  (4, 1),
#  (5, 9),
#  (6, 11),
#  (7, 15),
#  (8, 14),
#  (9, 28),
#  (10, 21),
#  (11, 52),
#  (12, 56),
#  (13, 57),
#  (14, 75),
#  (15, 81),
#  (16, 71),
#  (17, 78),
#  (18, 85),
#  (19, 90),
#  (20, 104),
#  (21, 99),
#  (22, 95),
#  (23, 102),
#  (24, 99),
#  (25, 109),
#  (26, 122),
#  (27, 114),
#  (28, 96),
#  (29, 95),
#  (30, 120),
#  (31, 98),
#  (32, 105),
#  (33, 116),
#  (34, 113),
#  (35, 86),
#  (36, 97),
#  (37, 98),
#  (38, 79),
#  (39, 97),
#  (40, 86),
#  (41, 113),
#  (42, 89),
#  (43, 71),
#  (44, 81),
#  (45, 73),
#  (46, 72),
#  (47, 69),
#  (48, 59),
#  (49, 41),
#  (50, 45),
#  (51, 41),
#  (52, 39),
#  (53, 29),
#  (54, 38),
#  (55, 26),
#  (56, 25),
#  (57, 30),
#  (58, 25),
#  (59, 18),
#  (60, 21),
#  (61, 20),
#  (62, 16),
#  (63, 16),
#  (64, 12),
#  (65, 8),
#  (66, 6),
#  (67, 2),
#  (68, 4),
#  (69, 4),
#  (70, 2),
#  (71, 0),
#  (72, 2),
#  (73, 0),
#  (74, 1)]

# %%
# Export a weights matrix as a .gal file for the 2015 sales
gal = pysal.open('./data/stpete_sales_2015.gal','w')
gal.write(wt)
gal.close()

# %%
# Create the spatial lag for a feature in 2015 sales
f = pysal.open("./data/stpete_sales_2015.dbf")
f.header
y = np.array(f.by_col['MEDHHINC'])
yl = pysal.lag_spatial(wt,y)
yl
# Out:
# array([ 2333272.,  3116603.,  3203971., ...,  2520874.,  2979909.,
#         2747461.])

# %%
# Append this and write the shapefile
stp_sales_2015['medinc_lag'] = yl.tolist()
stp_sales_2015.to_file('./data/stpete_sales_2015.shp')
stp_sales_2015.head()
# Out:
#    AVE_FAM_SZ  AVE_HH_SZ  CentroidX  CentroidY  HS_PER_AC  MEDFINCOME  \
# 0    2.777506       2.19 -82.642882  27.810570   4.596851       68229
# 1    2.777506       2.19 -82.646179  27.811467   4.596851       68229
# 2    2.777506       2.19 -82.644930  27.812377   4.596851       68229
# 3    2.777506       2.19 -82.643034  27.813685   4.596851       68229
# 4    2.777506       2.19 -82.644526  27.813679   4.596851       68229
#
#    MEDHHINC  MEDOOHVAL  MED_AGE  PCT_AMERI     ...      tif_flag_t  \
# 0     54321     125200       46        0.0     ...            None
# 1     54321     125200       46        0.0     ...            None
# 2     54321     125200       46        0.0     ...            None
# 3     54321     125200       46        0.0     ...            None
# 4     54321     125200       46        0.0     ...            None
#
#    tot_effect  tot_gross_  tot_living  total_livi  views  year_built  \
# 0        1164        1386        1048           1   None        1960
# 1        1672        2102        1486           1   None        1986
# 2        1626        1872        1468           1   None        1979
# 3        1855        2440        1680           1   None        1967
# 4        1524        1841        1453           1   None        1942
#
#            x          y  medinc_lag
# 0 -82.642882  27.810570   2333272.0
# 1 -82.646179  27.811467   3116603.0
# 2 -82.644930  27.812377   3203971.0
# 3 -82.643034  27.813685   2426029.0
# 4 -82.644526  27.813679   2777055.0
#
# [5 rows x 102 columns]

# %%
# Calculate the Moran's I for 2015 sales
f = pysal.open("./data/stpete_sales_2015.dbf")
f.header
y = np.array(f.by_col['price'])
y = y.astype(int)
mi = pysal.Moran(y, wt, two_tailed=False)
mi.I
# Out:
# 0.51024209394158593

# %%
# Calculate pseudo significance for Global Moran's I
np.random.seed(12345)
mir = pysal.Moran(y, wt, permutations = 9999)
mir.p_sim
# Out:
# 0.0001

# %%
# Calculate the LISA statistic for 2015 sales
lm = pysal.Moran_Local(y,wt)
lm.n
# len(lm.Is)
# lm.p_sim
lm.Is
lm.p_sim
# Out:
# array([ 0.255,  0.222,  0.493, ...,  0.263,  0.429,  0.434])

# %%
# Add the lisa values to the 2015 sales as a new feature
stp_sales_2015['lisa'] = lm.Is.tolist()
stp_sales_2015.head()
# Out:
#    AVE_FAM_SZ  AVE_HH_SZ  CentroidX  CentroidY  HS_PER_AC  MEDFINCOME  \
# 0    2.777506       2.19 -82.642882  27.810570   4.596851       68229
# 1    2.777506       2.19 -82.646179  27.811467   4.596851       68229
# 2    2.777506       2.19 -82.644930  27.812377   4.596851       68229
# 3    2.777506       2.19 -82.643034  27.813685   4.596851       68229
# 4    2.777506       2.19 -82.644526  27.813679   4.596851       68229
#
#    MEDHHINC  MEDOOHVAL  MED_AGE  PCT_AMERI    ...     tot_effect  tot_gross_  \
# 0     54321     125200       46        0.0    ...           1164        1386
# 1     54321     125200       46        0.0    ...           1672        2102
# 2     54321     125200       46        0.0    ...           1626        1872
# 3     54321     125200       46        0.0    ...           1855        2440
# 4     54321     125200       46        0.0    ...           1524        1841
#
#    tot_living  total_livi  views  year_built          x          y  \
# 0        1048           1   None        1960 -82.642882  27.810570
# 1        1486           1   None        1986 -82.646179  27.811467
# 2        1468           1   None        1979 -82.644930  27.812377
# 3        1680           1   None        1967 -82.643034  27.813685
# 4        1453           1   None        1942 -82.644526  27.813679
#
#    medinc_lag      lisa
# 0   2333272.0 -0.007315
# 1   3116603.0  0.007635
# 2   3203971.0 -0.000506
# 3   2426029.0 -0.019241
# 4   2777055.0 -0.014889
#
# [5 rows x 103 columns]

# %%
# Write it to the original shapefile
stp_sales_2015.to_file('./data/stpete_sales_2015.shp')
